# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeswinkuttiyani/Python_CaseStudy/blob/main/CaseStudy_Python_JeswinJose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
employees = [
    {"id":101, "name":"Alice", "department":"Data", "salary":65000, "rating":4.5},
    {"id":102, "name":"Bob", "department":"AI", "salary":72000, "rating":4.8},
    {"id":103, "name":"Charlie", "department":"Web", "salary":58000, "rating":3.9},
    {"id":104, "name":"David", "department":"Data", "salary":61000, "rating":4.2},
    {"id":105, "name":"Eva", "department":"AI", "salary":75000, "rating":4.9},
    {"id":106, "name":"Frank", "department":"Cloud", "salary":68000, "rating":4.1},
    {"id":107, "name":"Grace", "department":"Web", "salary":59000, "rating":3.8},
    {"id":108, "name":"Helen", "department":"Data", "salary":70000, "rating":4.6}
]
salary_sum=0
HSalary=0
LSalary=100000000
for emp in employees:
      salary_sum=salary_sum+emp["salary"]
      if emp["salary"]>HSalary:
            HSalary=emp["salary"]
      if emp["salary"]<LSalary:
            LSalary=emp["salary"]
print(f"\nTotal Employees: {len(employees)}")
print(f"\nAverage Salary: {salary_sum/len(employees)}")
print("Highest Salary: ",HSalary)
print("Lowest Salary: ",LSalary)



print("\nEmployees with Salary > 65000 and Rating >= 4.5")
for employee in employees:
    if employee["salary"] > 65000 and employee["rating"] >= 4.5:
        print(employee["name"])



employee_dic={}
for emp in employees:
    employee_dic[emp["id"]] = emp["name"]
print("\nEmployee Dictionary")
print(employee_dic)


names = []
for emp in employees:
    names.append(emp["name"])
names.sort()
names.reverse()
print("\nFirst Three Employee Names")
for i in range(3):
    print(names[i])


ids = []
for emp in employees:
    ids.append(emp["id"])
employee_ids = tuple(ids)
print("\nEmployee ID Tuple")
print(employee_ids)
print("Maximum Employee ID:", max(employee_ids))
print("Minimum Employee ID:", min(employee_ids))


dept=[]
for emp in employees:
    dept.append(emp["department"])
dept=set(dept)
print("\nDepartment")
print(dept)


n=int(input("Enter Employee ID: "))
found = False
for emp in employees:
    if emp["id"] == n:
        print("\nEmployee Found")
        print("ID:", employee["id"])
        print("Name:", employee["name"])
        print("Department:", employee["department"])
        print("Salary:", employee["salary"])
        print("Rating:", employee["rating"])
        found = True
        break
if found == False:
    print("\nEmployee Not Found")
# Out:
# Enter Employee ID: 102
#
# Total Employees: 8
#
# Average Salary: 66000.0
# Highest Salary:  75000
# Lowest Salary:  58000
#
# Employees with Salary > 65000 and Rating >= 4.5
# Bob
# Eva
# Helen
#
# Employee Dictionary
# {101: 'Alice', 102: 'Bob', 103: 'Charlie', 104: 'David', 105: 'Eva', 106: 'Frank', 107: 'Grace', 108: 'Helen'}
#
# First Three Employee Names
# Helen
# Grace
# Frank
#
# Employee ID Tuple
# (101, 102, 103, 104, 105, 106, 107, 108)
# Maximum Employee ID: 108
# Minimum Employee ID: 101
#
# Department
# {'AI', 'Cloud', 'Data', 'Web'}
#
# Employee Found
# ID: 108
# Name: Helen
# Department: Data
# Salary: 70000
# Rating: 4.6
